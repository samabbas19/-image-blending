# %%
from PIL import Image
import numpy as np
inp = Image.open(r"fr_jpg.jpg")
inp
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1600x646>

# %%
news = Image.open(r"bg_jpg.jpg")
news
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1600x646>

# %%
inp = np.array(inp)
news= np.array(news)

# %%
lower_green = np.array([0, 100, 0])
upper_green = np.array([100, 255, 100])
green=[47,171,39]
arr=[]
for i in range(len(inp)) :
    row=[]
    for j in range(len(inp[0])) :
        if all(inp[i][j]>=lower_green) and all(inp[i][j]<=upper_green):
            row.append(news[i][j])
        else:
            row.append(inp[i][j])
    arr.append(row)
# new = np.where( (inp>=lower_green) & (inp<=upper_green),news,inp)

# %%
ar2 = np.array(arr)
ar2.shape
# Out:
# (646, 1600, 3)

# %%
Image.fromarray(ar2)
# Out:
# <PIL.Image.Image image mode=RGB size=1600x646>
